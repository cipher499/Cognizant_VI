# %% [markdown]
# ---
# ## **Feature engineering, Model building & evaluation: Cognizant Virtual Internship**
#
# ### **@author: Shwetank Goswami**
#
# ### **GitHub: cipher499**
#
# #### date: 24/07/23
#
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
# load the sales data
sales_df = pd.read_csv("sales.csv")
sales_df.head()
# Out:
#    Unnamed: 0                        transaction_id            timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# ...

# %%
# drop the first column
sales_df.drop('Unnamed: 0', axis=1, inplace=True)
sales_df
# Out:
#                             transaction_id            timestamp  \
# 0     a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1     931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2     ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3     157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4     a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# ...                                    ...                  ...
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
#                                 product_id           category customer_type  \
# 0     3bc6c1ea-0198-46de-9ffd-514ae3338713              fruit          gold
# ...

# %%
# load the stock levels data
stock_df = pd.read_csv("sensor_stock_levels.csv")
stock_df
# Out:
#        Unnamed: 0                                    id            timestamp  \
# 0               0  4220e505-c247-478d-9831-6b9f87a4488a  2022-03-07 12:13:02
# 1               1  f2612b26-fc82-49ea-8940-0751fdd4d9ef  2022-03-07 16:39:46
# 2               2  989a287f-67e6-4478-aa49-c3a35dac0e2e  2022-03-01 18:17:43
# 3               3  af8e5683-d247-46ac-9909-1a77bdebefb2  2022-03-02 14:29:09
# 4               4  08a32247-3f44-4002-85fb-c198434dd4bb  2022-03-02 13:46:18
# ...           ...                                   ...                  ...
# 14995       14995  b9bf6788-09f3-490b-959b-dc5b55edb4b6  2022-03-04 10:52:50
# 14996       14996  9ff1cc01-020f-491a-bafd-13552dccff44  2022-03-02 12:25:48
# 14997       14997  4d8101de-e8a2-4af9-9764-7a3a22aa7084  2022-03-03 17:36:44
# 14998       14998  5f2a7b1e-b3c4-4395-8425-c960e22f701d  2022-03-02 19:42:47
# 14999       14999  af6f4493-e49d-4dcb-951d-308e6cce267b  2022-03-06 17:18:27
#
# ...

# %%
# drop the first column
stock_df.drop('Unnamed: 0', axis=1, inplace=True)
stock_df.head()
# Out:
#                                      id            timestamp  \
# 0  4220e505-c247-478d-9831-6b9f87a4488a  2022-03-07 12:13:02
# 1  f2612b26-fc82-49ea-8940-0751fdd4d9ef  2022-03-07 16:39:46
# 2  989a287f-67e6-4478-aa49-c3a35dac0e2e  2022-03-01 18:17:43
# 3  af8e5683-d247-46ac-9909-1a77bdebefb2  2022-03-02 14:29:09
# 4  08a32247-3f44-4002-85fb-c198434dd4bb  2022-03-02 13:46:18
#
#                              product_id  estimated_stock_pct
# 0  f658605e-75f3-4fed-a655-c0903f344427                 0.75
# 1  de06083a-f5c0-451d-b2f4-9ab88b52609d                 0.48
# 2  ce8f3a04-d1a4-43b1-a7c2-fa1b8e7674c8                 0.58
# 3  c21e3ba9-92a3-4745-92c2-6faef73223f7                 0.79
# 4  7f478817-aa5b-44e9-9059-8045228c9eb0                 0.22

# %%
# load the temperature data
temp_df = pd.read_csv("sensor_storage_temperature.csv")
temp_df
# Out:
#        Unnamed: 0                                    id            timestamp  \
# 0               0  d1ca1ef8-0eac-42fc-af80-97106efc7b13  2022-03-07 15:55:20
# 1               1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18  2022-03-01 09:18:22
# 2               2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3  2022-03-04 15:12:26
# 3               3  9500357b-ce15-424a-837a-7677b386f471  2022-03-02 12:30:42
# 4               4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa  2022-03-05 09:09:33
# ...           ...                                   ...                  ...
# 23885       23885  17bcff56-9965-4e9f-ad5f-107f0f3be93f  2022-03-01 10:40:43
# 23886       23886  51d4eb44-04bd-4d6a-b777-0653bc173303  2022-03-05 17:07:49
# 23887       23887  bbcacfc4-3b59-47ee-b9e1-7dd3bd588748  2022-03-01 16:15:41
# 23888       23888  5c4d567b-4bcf-4fcd-86b7-e2db5de6e439  2022-03-07 14:44:52
# 23889       23889  589c28e1-f1f3-4efb-af6d-9f194c4d7d5b  2022-03-01 16:33:41
#
#        temperature
# 0             2.96
# ...

# %%
# drop the first column
temp_df.drop('Unnamed: 0', axis=1, inplace=True)
temp_df.head()
# Out:
#                                      id            timestamp  temperature
# 0  d1ca1ef8-0eac-42fc-af80-97106efc7b13  2022-03-07 15:55:20         2.96
# 1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18  2022-03-01 09:18:22         1.88
# 2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3  2022-03-04 15:12:26         1.78
# 3  9500357b-ce15-424a-837a-7677b386f471  2022-03-02 12:30:42         2.18
# 4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa  2022-03-05 09:09:33         1.38

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7829 non-null   object
#  1   timestamp       7829 non-null   object
#  2   product_id      7829 non-null   object
#  3   category        7829 non-null   object
#  4   customer_type   7829 non-null   object
#  5   unit_price      7829 non-null   float64
#  6   quantity        7829 non-null   int64
#  7   total           7829 non-null   float64
#  8   payment_type    7829 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 550.6+ KB

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   15000 non-null  object
#  1   timestamp            15000 non-null  object
#  2   product_id           15000 non-null  object
#  3   estimated_stock_pct  15000 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 468.9+ KB

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23890 entries, 0 to 23889
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           23890 non-null  object
#  1   timestamp    23890 non-null  object
#  2   temperature  23890 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 560.0+ KB

# %% [markdown]
# ---
# * The timestamp column in all three dataframes is of the datatype string. We need to convert that into the datetime datatype.
# ---

# %%
def convert_to_datetime(data: pd.DataFrame = None, column: str = None):
    dummy = data.copy()
    dummy[column] = pd.to_datetime(dummy[column], format = '%Y-%m-%d %H:%M:%S')
    return dummy

# %%
sales_df = convert_to_datetime(sales_df, 'timestamp')
stock_df = convert_to_datetime(stock_df, 'timestamp')
temp_df = convert_to_datetime(temp_df, 'timestamp')

# %%
sales_df.head()
# Out:
#                          transaction_id           timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
stock_df.head()
# Out:
#                                      id           timestamp  \
# 0  4220e505-c247-478d-9831-6b9f87a4488a 2022-03-07 12:13:02
# 1  f2612b26-fc82-49ea-8940-0751fdd4d9ef 2022-03-07 16:39:46
# 2  989a287f-67e6-4478-aa49-c3a35dac0e2e 2022-03-01 18:17:43
# 3  af8e5683-d247-46ac-9909-1a77bdebefb2 2022-03-02 14:29:09
# 4  08a32247-3f44-4002-85fb-c198434dd4bb 2022-03-02 13:46:18
#
#                              product_id  estimated_stock_pct
# 0  f658605e-75f3-4fed-a655-c0903f344427                 0.75
# 1  de06083a-f5c0-451d-b2f4-9ab88b52609d                 0.48
# 2  ce8f3a04-d1a4-43b1-a7c2-fa1b8e7674c8                 0.58
# 3  c21e3ba9-92a3-4745-92c2-6faef73223f7                 0.79
# 4  7f478817-aa5b-44e9-9059-8045228c9eb0                 0.22

# %%
temp_df.head()
# Out:
#                                      id           timestamp  temperature
# 0  d1ca1ef8-0eac-42fc-af80-97106efc7b13 2022-03-07 15:55:20         2.96
# 1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:18:22         1.88
# 2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3 2022-03-04 15:12:26         1.78
# 3  9500357b-ce15-424a-837a-7677b386f471 2022-03-02 12:30:42         2.18
# 4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa 2022-03-05 09:09:33         1.38

# %% [markdown]
# ---
# * For merging the three dataframes, we need to merge them on the timestamp column since it is common amongst all three dataframes.
# ---

# %%
from datetime import datetime

def timestamp_to_hourly(data: pd.DataFrame = None, column: str = None):
    dummy = data.copy()
    new_ts = dummy[column].tolist()
    new_ts = [i.strftime('%Y-%m-%d %H:00:00') for i in new_ts]
    new_ts = [datetime.strptime(i, '%Y-%m-%d %H:00:00') for i in new_ts]
    dummy[column] = new_ts
    return dummy

# %%
sales_df = timestamp_to_hourly(sales_df, 'timestamp')
sales_df.head()
# Out:
#                          transaction_id           timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:00:00
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:00:00
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:00:00
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:00:00
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:00:00
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
stock_df = timestamp_to_hourly(stock_df, 'timestamp')
stock_df.head()
# Out:
#                                      id           timestamp  \
# 0  4220e505-c247-478d-9831-6b9f87a4488a 2022-03-07 12:00:00
# 1  f2612b26-fc82-49ea-8940-0751fdd4d9ef 2022-03-07 16:00:00
# 2  989a287f-67e6-4478-aa49-c3a35dac0e2e 2022-03-01 18:00:00
# 3  af8e5683-d247-46ac-9909-1a77bdebefb2 2022-03-02 14:00:00
# 4  08a32247-3f44-4002-85fb-c198434dd4bb 2022-03-02 13:00:00
#
#                              product_id  estimated_stock_pct
# 0  f658605e-75f3-4fed-a655-c0903f344427                 0.75
# 1  de06083a-f5c0-451d-b2f4-9ab88b52609d                 0.48
# 2  ce8f3a04-d1a4-43b1-a7c2-fa1b8e7674c8                 0.58
# 3  c21e3ba9-92a3-4745-92c2-6faef73223f7                 0.79
# 4  7f478817-aa5b-44e9-9059-8045228c9eb0                 0.22

# %%
temp_df = timestamp_to_hourly(temp_df, 'timestamp')
temp_df.head()
# Out:
#                                      id           timestamp  temperature
# 0  d1ca1ef8-0eac-42fc-af80-97106efc7b13 2022-03-07 15:00:00         2.96
# 1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:00:00         1.88
# 2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3 2022-03-04 15:00:00         1.78
# 3  9500357b-ce15-424a-837a-7677b386f471 2022-03-02 12:00:00         2.18
# 4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa 2022-03-05 09:00:00         1.38

# %% [markdown]
# ---
# * Multiple rows have the same timestamp in all the dataframes. We'll group these rows.
# * In the sales dataframe, rows can be grouped by both 'timestamp' and 'product_id' columns.
# * When we aggregate, we must choose which columns to aggregate by the grouping.
# ---

# %%
sales_df.columns
# Out:
# Index(['transaction_id', 'timestamp', 'product_id', 'category',
#        'customer_type', 'unit_price', 'quantity', 'total', 'payment_type'],
#       dtype='object')

# %%
sales_agg = sales_df.groupby(['timestamp', 'product_id']).agg({'quantity':'sum'}).reset_index()
sales_agg
# Out:
#                timestamp                            product_id  quantity
# 0    2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03         3
# 1    2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0         3
# 2    2022-03-01 09:00:00  03a2557a-aa12-4add-a6d4-77dc36342067         3
# 3    2022-03-01 09:00:00  049b2171-0eeb-4a3e-bf98-0c290c7821da         7
# 4    2022-03-01 09:00:00  04da844d-8dba-4470-9119-e534d52a03a0        11
# ...                  ...                                   ...       ...
# 6212 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9         3
# 6213 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443         3
# 6214 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43         2
# 6215 2022-03-07 19:00:00  fd66ac0b-3498-4613-8ec0-764686b0d864         1
# 6216 2022-03-07 19:00:00  fd77b5cb-498c-40ca-95d1-0f87f13dd0d8         1
#
# [6217 rows x 3 columns]

# %%
len(sales_agg['timestamp'].unique())
# Out:
# 77

# %%
stock_agg = stock_df.groupby(['timestamp', 'product_id']).agg({'estimated_stock_pct':'mean'}).reset_index()
stock_agg
# Out:
#                 timestamp                            product_id  \
# 0     2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1     2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2     2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3     2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4     2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
# ...                   ...                                   ...
# 10840 2022-03-07 19:00:00  ecac012c-1dec-41d4-9ebd-56fb7166f6d9
# 10841 2022-03-07 19:00:00  ed7f6b14-67c9-42a4-8576-c803020eedda
# 10842 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9
# 10843 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443
# 10844 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43
#
#        estimated_stock_pct
# 0                     0.89
# 1                     0.14
# 2                     0.67
# 3                     0.82
# 4                     0.05
# ...                    ...
# ...

# %%
len(stock_agg['timestamp'].unique())
# Out:
# 77

# %%
temp_agg = temp_df.groupby(['timestamp']).agg({'temperature':'mean'}).reset_index()
temp_agg
# Out:
#              timestamp  temperature
# 0  2022-03-01 09:00:00    -0.028850
# 1  2022-03-01 10:00:00     1.284314
# 2  2022-03-01 11:00:00    -0.560000
# 3  2022-03-01 12:00:00    -0.537721
# 4  2022-03-01 13:00:00    -0.188734
# ..                 ...          ...
# 72 2022-03-07 15:00:00    -0.943848
# 73 2022-03-07 16:00:00    -0.230631
# 74 2022-03-07 17:00:00    -0.003988
# 75 2022-03-07 18:00:00     0.409693
# 76 2022-03-07 19:00:00    -0.165077
#
# [77 rows x 2 columns]

# %%
# merge the stock & sales aggregate dataframes on common columns
merge1 = stock_agg.merge(sales_agg, on=['timestamp', 'product_id'], how='left')
merge1
# Out:
#                 timestamp                            product_id  \
# 0     2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1     2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2     2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3     2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4     2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
# ...                   ...                                   ...
# 10840 2022-03-07 19:00:00  ecac012c-1dec-41d4-9ebd-56fb7166f6d9
# 10841 2022-03-07 19:00:00  ed7f6b14-67c9-42a4-8576-c803020eedda
# 10842 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9
# 10843 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443
# 10844 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43
#
#        estimated_stock_pct  quantity
# 0                     0.89       3.0
# 1                     0.14       3.0
# 2                     0.67       NaN
# 3                     0.82       NaN
# ...

# %%
# merge this df with the temerature aggregate df
merged_df = merge1.merge(temp_agg, on=['timestamp'], how='left')
merged_df
# Out:
#                 timestamp                            product_id  \
# 0     2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1     2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2     2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3     2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4     2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
# ...                   ...                                   ...
# 10840 2022-03-07 19:00:00  ecac012c-1dec-41d4-9ebd-56fb7166f6d9
# 10841 2022-03-07 19:00:00  ed7f6b14-67c9-42a4-8576-c803020eedda
# 10842 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9
# 10843 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443
# 10844 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43
#
#        estimated_stock_pct  quantity  temperature
# 0                     0.89       3.0    -0.028850
# 1                     0.14       3.0    -0.028850
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            10845 non-null  datetime64[ns]
#  1   product_id           10845 non-null  object
#  2   estimated_stock_pct  10845 non-null  float64
#  3   quantity             3067 non-null   float64
#  4   temperature          10845 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 508.4+ KB

# %%
# replace the null values in the quantity column with 0
merged_df['quantity'] = merged_df['quantity'].fillna(0)
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            10845 non-null  datetime64[ns]
#  1   product_id           10845 non-null  object
#  2   estimated_stock_pct  10845 non-null  float64
#  3   quantity             10845 non-null  float64
#  4   temperature          10845 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 508.4+ KB

# %% [markdown]
# * Add more features from the original dataframes

# %%
cat = sales_df[['product_id', 'category']]
cat = cat.drop_duplicates()

price = sales_df[['product_id', 'unit_price']]
price = price.drop_duplicates()

# %%
merged_df = merged_df.merge(cat, on=['product_id'], how='left')
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature       category
# 0                 0.89       3.0     -0.02885        kitchen
# 1                 0.14       3.0     -0.02885     vegetables
# 2                 0.67       0.0     -0.02885  baby products
# 3                 0.82       0.0     -0.02885      beverages
# 4                 0.05       0.0     -0.02885           pets

# %%
merged_df = merged_df.merge(price, on=['product_id'], how='left')
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature       category  unit_price
# 0                 0.89       3.0     -0.02885        kitchen       11.19
# 1                 0.14       3.0     -0.02885     vegetables        1.49
# 2                 0.67       0.0     -0.02885  baby products       14.19
# 3                 0.82       0.0     -0.02885      beverages       20.19
# 4                 0.05       0.0     -0.02885           pets        8.19

# %% [markdown]
# ### Feature Engineering

# %%
# add columns for day of month, day of week, hour of day
merged_df['day_of_month'] = merged_df['timestamp'].dt.day
merged_df['day_of_week'] = merged_df['timestamp'].dt.dayofweek
merged_df['day_of_hour'] = merged_df['timestamp'].dt.hour
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature       category  unit_price  \
# 0                 0.89       3.0     -0.02885        kitchen       11.19
# 1                 0.14       3.0     -0.02885     vegetables        1.49
# 2                 0.67       0.0     -0.02885  baby products       14.19
# 3                 0.82       0.0     -0.02885      beverages       20.19
# 4                 0.05       0.0     -0.02885           pets        8.19
#
#    day_of_month  day_of_week  day_of_hour
# 0             1            1            9
# 1             1            1            9
# ...

# %% [markdown]
# * For model building, we have to convert all the categorical variables into numeric variables.

# %%
merged_df = pd.get_dummies(merged_df, columns=['category'])
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature  unit_price  day_of_month  \
# 0                 0.89       3.0     -0.02885       11.19             1
# 1                 0.14       3.0     -0.02885        1.49             1
# 2                 0.67       0.0     -0.02885       14.19             1
# 3                 0.82       0.0     -0.02885       20.19             1
# 4                 0.05       0.0     -0.02885        8.19             1
#
#    day_of_week  day_of_hour  category_baby products  ...  category_meat  \
# 0            1            9                       0  ...              0
# ...

# %% [markdown]
# * The column 'product_id' is a non-numeric column and offers us no relevant information. Each combination of timestamp and product_id represents a new row, and dropping the latter would make the df ready for model building.
# * Also, the column timestamp is now of no use as we've extracted other features of it.

# %%
merged_df.drop('product_id', axis=1, inplace=True)
merged_df.drop('timestamp', axis=1, inplace=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   estimated_stock_pct             10845 non-null  float64
#  1   quantity                        10845 non-null  float64
#  2   temperature                     10845 non-null  float64
#  3   unit_price                      10845 non-null  float64
#  4   day_of_month                    10845 non-null  int64
#  5   day_of_week                     10845 non-null  int64
#  6   day_of_hour                     10845 non-null  int64
#  7   category_baby products          10845 non-null  uint8
#  8   category_baked goods            10845 non-null  uint8
#  9   category_baking                 10845 non-null  uint8
#  10  category_beverages              10845 non-null  uint8
#  11  category_canned foods           10845 non-null  uint8
# ...

# %% [markdown]
# ## Model building & evaluation

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
X = merged_df.drop('estimated_stock_pct', axis=1)
y = merged_df['estimated_stock_pct']

# %%
print(X.shape, y.shape)
# Out:
# (10845, 28) (10845,)

# %%
from sklearn.preprocessing import StandardScaler
K = 10
split = 0.20

# %%
accuracy = []

for fold in range(0, K):
    # Create training and test samples
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split, random_state=42)

    # Scale X data; we scale the data because it helps the algorithm to converge
    scaler = StandardScaler()
    scaler.fit(X_train)
    model = RandomForestRegressor()
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    # Train model
    trained_model = model.fit(X_train, y_train)

    # Generate predictions on test sample
    y_pred = trained_model.predict(X_test)

    # Compute accuracy using mean absolute error
    mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
    accuracy.append(mae)
    print(f"{model} Fold {fold + 1}: MAE = {mae:.3f}")

print(f"Average MAE for {model}: {(sum(accuracy) / len(accuracy)):.2f}")
# Out:
# RandomForestRegressor() Fold 1: MAE = 0.236
# RandomForestRegressor() Fold 2: MAE = 0.236
# RandomForestRegressor() Fold 3: MAE = 0.236
# RandomForestRegressor() Fold 4: MAE = 0.236
# RandomForestRegressor() Fold 5: MAE = 0.236
# RandomForestRegressor() Fold 6: MAE = 0.234
# RandomForestRegressor() Fold 7: MAE = 0.235
# RandomForestRegressor() Fold 8: MAE = 0.235
# RandomForestRegressor() Fold 9: MAE = 0.236
# RandomForestRegressor() Fold 10: MAE = 0.236
# Average MAE for RandomForestRegressor(): 0.24

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %% [markdown]
# ### Create a feature importance plot

# %%
X_df = merged_df.drop('estimated_stock_pct', axis=1)

# %%
features = [i.split("__")[0] for i in X_df.columns]
importances = model.feature_importances_
sorted_indices = np.argsort(importances)

# Plot the feature importances
fig, ax = plt.subplots(figsize=(15, 15))
ax.barh(range(len(importances)), importances[sorted_indices], color='dodgerblue', edgecolor='black')
ax.set_yticks(range(len(importances)))
ax.set_yticklabels([features[i] for i in sorted_indices], fontsize=12)
ax.set_xlabel('Relative Importance', fontsize=12)
ax.set_title('Feature Importances', fontsize=14)
ax.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Annotate the importance values on the bars
for i, v in enumerate(importances[sorted_indices]):
    ax.text(v, i, f"{v:.3f}", ha='left', va='center', fontsize=10)

plt.show()

# %% [markdown]
# ----
# From the plot it is evident that:
# * Unit price, temperature, and day of hour were the best predictors of stock levels
# * Product categories do not tell us much about the stock levels

# %%
merged_df.to_csv('modeling.csv', index=False)
